# %% [markdown]
# <center><h2><span style="color:darkblue">Numerical Optimization with Python</span></h2></center>
# <center><h3><span style="color:darkblue">Programming Assignment 01</span></h3></center>
# <center><p><strong>Noa Ben Davis, ID: 300950565</strong></p></center>

# %% [markdown]
# <h3><span style="color:darkgreen">Initial imports</span></h3>

# %%
import matplotlib.pyplot as plt
import numpy as np
from ex1_tests.examples import quadratic_circles, quadratic_ellipses, quadratic_rotated_ellipses
from ex1_tests.examples import rosenbrock_func_example,linear_function, smoothed_corner_triangle_function
from src.unconstrained_min import line_search_minimization
from src.utils import plot_contour_lines, plot_function_values
from ex1_tests.test_unconstrained_min import main_run

# %% [markdown]
# <h3><span style="color:darkgreen">Quadratic Example 1: Circles</span></h3>

# %%
main_run(quadratic_circles, 'Quadratic Example: Circles', add_full_prints=False)
# Out:
# **********************************************************************
# ***** Running test: Quadratic Example: Circles *****
# **********************************************************************
# i) Gradient Descent Finished after 1 Iterrations: Final location at x = [0. 0.], with f(x) = 0.0, success = True
# ii) Newton Finished after 1 Iterrations: Final location at x = [0. 0.], with f(x) = 0.0, success = True

# %% [markdown]
# <h3><span style="color:darkgreen">Quadratic Example 2: Ellipses</span></h3>

# %%
main_run(quadratic_ellipses, 'Quadratic Example: Ellipses', add_full_prints=False)
# Out:
# **********************************************************************
# ***** Running test: Quadratic Example: Ellipses *****
# **********************************************************************
# i) Gradient Descent Finished after 100 Iterrations: Final location at x = [0.11271997 0.0008856 ], with f(x) = 0.012784220095399295, success = False
# ii) Newton Finished after 1 Iterrations: Final location at x = [0. 0.], with f(x) = 0.0, success = True

# %% [markdown]
# <h3><span style="color:darkgreen">Quadratic Example 3: Rotated Ellipses</span></h3>

# %%
main_run(quadratic_rotated_ellipses, 'Quadratic Example: Rotated Ellipses', add_full_prints=False)
# Out:
# **********************************************************************
# ***** Running test: Quadratic Example: Rotated Ellipses *****
# **********************************************************************
# i) Gradient Descent Finished after 100 Iterrations: Final location at x = [0.07682763 0.13062022], with f(x) = 0.02311258419270041, success = False
# ii) Newton Finished after 1 Iterrations: Final location at x = [0. 0.], with f(x) = 0.0, success = True

# %% [markdown]
# <h3><span style="color:darkgreen">Example 4: Rosenbrock Function</span></h3>

# %%
main_run(rosenbrock_func_example, 'Rosenbrock Function', x0=[-1,2], max_iter=10000, add_full_prints=False)
# Out:
# **********************************************************************
# ***** Running test: Rosenbrock Function *****
# **********************************************************************
# i) Gradient Descent Finished after 2205 Iterrations: Final location at x = [0.99009601 0.98019118], with f(x) = 9.906762004938443e-05, success = True
# ii) Newton Finished after 20 Iterrations: Final location at x = [0.99999999 0.99999998], with f(x) = 2.7300933598972337e-16, success = True

# %% [markdown]
# <h3><span style="color:darkgreen">Example 5: Linear Function</span></h3>

# %%
main_run(linear_function, 'Linear Function', add_full_prints=False)
# Out:
# **********************************************************************
# ***** Running test: Linear Function *****
# **********************************************************************
# i) Gradient Descent Finished after 100 Iterrations: Final location at x = [ -99. -199.], with f(x) = -497.0, success = False
# Hessian is singular or not square - break
# ******************************
# ii) Newton Finished after 0 Iterrations: Final location at x = [1. 1.], with f(x) = 3.0, success = False

# %% [markdown]
# <h3><span style="color:darkgreen">Example 6: Smoothed Corner Triangle Function</span></h3>

# %%
main_run(smoothed_corner_triangle_function, 'Smoothed Corner Triangle Function', add_full_prints=False)
# Out:
# **********************************************************************
# ***** Running test: Smoothed Corner Triangle Function *****
# **********************************************************************
# i) Gradient Descent Finished after 22 Iterrations: Final location at x = [-3.46536273e-01  1.68470313e-05], with f(x) = 2.559266700074579, success = True
# ii) Newton Finished after 8 Iterrations: Final location at x = [-3.46573590e-01  6.80690347e-12], with f(x) = 2.5592666966582156, success = True

# %% [markdown]
# <h3><span style="color:darkgreen">Full outputs (no graphs)</span></h3>

# %%
main_run(quadratic_circles, 'Quadratic Example: Circles', add_plot=False)
main_run(quadratic_ellipses, 'Quadratic Example: Ellipses', add_plot=False)
main_run(quadratic_rotated_ellipses, 'Quadratic Example: Rotated Ellipses', add_plot=False)
main_run(rosenbrock_func_example, 'Rosenbrock Function', x0=[-1,2], max_iter=10000, add_plot=False)
main_run(linear_function, 'Linear Function', add_plot=False)
main_run(smoothed_corner_triangle_function, 'Smoothed Corner Triangle Function', add_plot=False)
# Out:
# **********************************************************************
# ***** Running test: Quadratic Example: Circles *****
# **********************************************************************
# #####################
#  # Gradient Descent #
# #####################
# Iteration 0: xk = [1. 1.], f(xk) = 2.0
# Reached stop condition at iteration 1: xk = [0. 0.], f(xk) = 0.0
# ****************************************************************************************************
#
# ###########
#  # Newton #
# ###########
# Iteration 0: xk = [1. 1.], f(xk) = 2.0
# Reached stop condition at iteration 1: xk = [0. 0.], f(xk) = 0.0
# ****************************************************************************************************
#
# **********************************************************************
# ***** Running test: Quadratic Example: Ellipses *****
# **********************************************************************
# #####################
#  # Gradient Descent #
# ...
